# %%
import pandas as pd

# %%
df=pd.read_csv('application_data_test.csv')

# %%
df
# Out:
#        SK_ID_CURR NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  \
# 0          331034         Cash loans           F            N               Y
# 1          242581         Cash loans           F            N               Y
# 2          281583         Cash loans           F            N               Y
# 3          255865         Cash loans           F            N               Y
# 4          389379    Revolving loans           M            N               N
# ...           ...                ...         ...          ...             ...
# 92249      229275         Cash loans           F            N               Y
# 92250      329443         Cash loans           F            N               Y
# 92251      362651         Cash loans           F            Y               Y
# 92252      273788         Cash loans           F            N               Y
# 92253      340650         Cash loans           F            N               Y
#
# ...
